# %%
from helper import nb_print

# %%
from letta import create_client 

client = create_client()
# this can be connected with client server but in this case
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from letta import create_client
#       3 client = create_client()
#
# ModuleNotFoundError: No module named 'letta'

# %%
! pip install letta
# Out:
# ...
#   Obtaining dependency information for letta from https://files.pythonhosted.org/packages/9f/72/de141c46cba16fee89ce3695a15e595f50e80ec230f6f373b985c7f589be/letta-0.6.30-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for alembic<2.0.0,>=1.13.3 from https://files.pythonhosted.org/packages/54/7e/ac0991d1745f7d755fc1cd381b3990a45b404b4d008fc75e2a983516fbfe/alembic-1.14.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for anthropic<0.44.0,>=0.43.0 from https://files.pythonhosted.org/packages/89/2b/63b167d76401f759c8c4ff0266042e60aac6fd3cc0685b27437ceaaf95eb/anthropic-0.43.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for brotli<2.0.0,>=1.1.0 from https://files.pythonhosted.org/packages/96/12/ad41e7fadd5db55459c4c401842b47f7fee51068f86dd2894dd0dcfc2d2a/Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl.metadata
# ...
